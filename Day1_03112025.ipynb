# %% [markdown]
# <a href="https://colab.research.google.com/github/azhar258/Advance_Data_Engineering/blob/main/Day1_03112025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
i = 10
j = 4+6
k = 2+8
l = 3+7

print(hex(id(i)))
print(hex(id(j)))
print(hex(id(k)))
print(hex(id(l)))
# Out:
# 0xb1d608
# 0xb1d608
# 0xb1d608
# 0xb1d608

# %%
import sys
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %%
# Given List
product_info1 = [101, 'pA', 1000.32, True]
print(type(product_info1))
# Out:
# <class 'list'>

# %%
print(product_info1[0])
print(product_info1[1])
print(product_info1[2])
print(product_info1[3])
# Out:
# 101
# pA
# 1000.32
# True

# %%
# tuple - record
product_info2 = (101,'pA',1000.32,True) # immutable
print(type(product_info2))
# Out:
# <class 'tuple'>

# %%
product_info2
# Out:
# (101, 'pA', 1000.32, True)

# %%
product_info2[0]
# Out:
# 101

# %%
product_info2[-1]
# Out:
# True

# %%
product_info3 = {'pid':101,'pname':'pA','pcost':1000.32,'pstatus':True}
print(type(product_info3))
# Out:
# <class 'dict'>

# %%
product_info3['pid']
# Out:
# 101

# %%
# list of list
product_list = [[101,'pA',1000],[102,'pB',2000],[103,'pC',3000]]
product_list
# Out:
# [[101, 'pA', 1000], [102, 'pB', 2000], [103, 'pC', 3000]]

# %%
product_list.append([104, 'pD', 3450])
product_list
# Out:
# [[101, 'pA', 1000], [102, 'pB', 2000], [103, 'pC', 3000], [104, 'pD', 3450]]

# %%
print(product_list[0])
print(product_list[1])
print(product_list[2])
print(product_list[3])
# Out:
# [101, 'pA', 1000]
# [102, 'pB', 2000]
# [103, 'pC', 3000]
# [104, 'pD', 3450]

# %%
print(product_list[1][0])
# Out:
# 102

# %%
# list of dict
product_list = [{'pid':101,'pname':'pA','pcost':1000},
                {'pid':102,'pname':'pB','pcost':2000},
                {'pid':103,'pname':'pC','pcost':3000}
               ]

# %%
product_list[0]
# Out:
# {'pid': 101, 'pname': 'pA', 'pcost': 1000}

# %%
product_list[0]['pname']
# Out:
# 'pA'

# %%
product_list[1]['pcost']
# Out:
# 2000

# %%
L = [["D1","D2","D3"],{"K1":"D4","K2":"D5"}]
L
# Out:
# [['D1', 'D2', 'D3'], {'K1': 'D4', 'K2': 'D5'}]

# %%
products = {}

products['pid'] = []
products['pname'] = []
products['pcost'] = []
products['pstatus'] = []

products
# Out:
# {'pid': [], 'pname': [], 'pcost': [], 'pstatus': []}

# %%
products['pid'].append(101)
products['pname'].append('pA')
products['pcost'].append(1001)
products['pstatus'].append(True)

products
# Out:
# {'pid': [101], 'pname': ['pA'], 'pcost': [1001], 'pstatus': [True]}

# %%
products['pid'].append(102)
products['pname'].append('pb')
products['pcost'].append(1002)
products['pstatus'].append(False)

products
# Out:
# {'pid': [101, 102],
#  'pname': ['pA', 'pb'],
#  'pcost': [1001, 1002],
#  'pstatus': [True, False]}

# %%
products['pid'].append(103)
products['pcost'].append(1003)
products['pname'].append('pc')
products['pstatus'].append(True)

products
# Out:
# {'pid': [101, 102, 103],
#  'pname': ['pA', 'pb', 'pc'],
#  'pcost': [1001, 1002, 1003],
#  'pstatus': [True, False, True]}

# %%
products={}
products['K1']={'pid':101,'pname':'pA','pcost':1000}
products['K2']={'pid':102,'pname':'pB','pcost':2000}
products['K3']={'pid':103,'pname':'pC','pcost':3000}
products['K4']={'pid':104,'pname':'pD','pcost':4000}
products
# Out:
# {'K1': {'pid': 101, 'pname': 'pA', 'pcost': 1000},
#  'K2': {'pid': 102, 'pname': 'pB', 'pcost': 2000},
#  'K3': {'pid': 103, 'pname': 'pC', 'pcost': 3000},
#  'K4': {'pid': 104, 'pname': 'pD', 'pcost': 4000}}

# %%
products['K1']
# Out:
# {'pid': 101, 'pname': 'pA', 'pcost': 1000}

# %%
products['K1']['pname']
# Out:
# 'pA'

# %%
data = [
  {
    "login": "ggobi",
    "id": 423638,
    "node_id": "MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==",
    "url": "https://api.github.com/orgs/ggobi",
    "repos_url": "https://api.github.com/orgs/ggobi/repos",
    "events_url": "https://api.github.com/orgs/ggobi/events",
    "hooks_url": "https://api.github.com/orgs/ggobi/hooks",
    "issues_url": "https://api.github.com/orgs/ggobi/issues",
    "members_url": "https://api.github.com/orgs/ggobi/members{/member}",
    "public_members_url": "https://api.github.com/orgs/ggobi/public_members{/member}",
    "avatar_url": "https://avatars.githubusercontent.com/u/423638?v=4",
    "description": ""
  }
]

# %%
data[0]['login']
data[0]['url']
# Out:
# 'https://api.github.com/orgs/ggobi'

# %%
L=[10,20,30,40,50]
L+100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1839814898.py in <cell line: 0>()
#       1 L=[10,20,30,40,50]
# ----> 2 L+100
#
# TypeError: can only concatenate list (not "int") to list

# %%
import numpy
numpy.array([])
# Out:
# array([], dtype=float64)

# %%
import numpy as np
np.array([])
# Out:
# array([], dtype=float64)

# %%
arr = np.array([10,20,30,40,50])
arr+100.56
# Out:
# array([110.56, 120.56, 130.56, 140.56, 150.56])

# %%
print(arr)
# Out:
# [10 20 30 40 50]

# %%
print(arr.dtype)
print(arr.shape)
# Out:
# int64
# (5,)

# %%
print(np.array([10,20,30]).dtype)
print(np.array([10,20,30.0]).dtype)
print(np.array([10,20,True]).dtype)
print(np.array([True,False]).dtype)
print(np.array([10,20,3.5,True]).dtype)
print('')
print(np.array([10,20,'data']).dtype)
# Out:
# int64
# float64
# int64
# bool
# float64
#
# <U21

# %%
np.array([10,20,30])+100
# Out:
# array([110, 120, 130])

# %%
np.array([10,20,'data'])+100
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /tmp/ipython-input-3731882456.py in <cell line: 0>()
# ----> 1 np.array([10,20,'data'])+100
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U21'), dtype('int64')) -> None

# %%
np.array([10,20,30]).ndim
# Out:
# 1

# %%
np.array([[10,20,30]]).ndim
# Out:
# 2

# %%
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr = np.array([[10,20,30]])
arr.ndim
# Out:
# 2

# %%
arr[0][0]
# Out:
# np.int64(10)

# %%
arr = np.array([[[10,20,30], [40,50,60]]])
print(arr.ndim, arr.shape)
print(arr)
# Out:
# 3 (1, 2, 3)
# [[[10 20 30]
#   [40 50 60]]]

# %%
arr.reshape(3,2,1)
# Out:
# array([[[10],
#         [20]],
#
#        [[30],
#         [40]],
#
#        [[50],
#         [60]]])

# %%
arr.reshape(6,1)
# Out:
# array([[10],
#        [20],
#        [30],
#        [40],
#        [50],
#        [60]])

# %%
L = [10,20,30,40,50]

total =0
for var in L:
  total += var
print(total)

arr1 = np.array(L)
print('from numpy', np.sum(arr1))
# Out:
# 150
# from numpy 150

# %%
np.mean(L)
# Out:
# np.float64(30.0)

# %%
np.median(L)
# Out:
# np.float64(30.0)

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(np.mean(arr))
# Out:
# 3.5

# %%
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.mean(arr, axis=1)
# Out:
# array([2., 5.])

# %%
np.mean(arr, axis=0)
# Out:
# array([2.5, 3.5, 4.5])

# %%
products = {'pid':[],'pname':[],'pcost':[]}
products['pid'].append(101)
products['pname'].append('pA')
products['pcost'].append(1000)
products
# Out:
# {'pid': [101], 'pname': ['pA'], 'pcost': [1000]}

# %%
products['pid'].append(102)
products['pname'].append('pB')
products['pcost'].append(2000)
products['pid'].append(103)
products['pname'].append('pC')
products['pcost'].append(3000)
products['pid'].append(104)
products['pname'].append('pD')
products['pcost'].append(4000)

products
# Out:
# {'pid': [101, 102, 103, 104],
#  'pname': ['pA', 'pB', 'pC', 'pD'],
#  'pcost': [1000, 2000, 3000, 4000]}

# %%
print(type(products))
# Out:
# <class 'dict'>

# %%
products['pcost']
# Out:
# [1000, 2000, 3000, 4000]

# %%
arr = np.array(products['pcost'])
np.sum(arr)
# Out:
# np.int64(10000)

# %%
np.max(arr)
# Out:
# np.int64(4000)

# %%
np.mean(arr)
# Out:
# np.float64(2500.0)

# %%
import pandas
pandas
# Out:
# <module 'pandas' from '/usr/local/lib/python3.12/dist-packages/pandas/__init__.py'>

# %%
print(pandas.Series)
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(pandas.DataFrame)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
arr = [10,20,30,40,50]

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.DataFrame(arr)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
products = {}
products['pid'] = [101,102,103]
products['pname'] = ['pA','pB','pC']
products['pcost'] = [1000,2000,3000]
products
# Out:
# {'pid': [101, 102, 103],
#  'pname': ['pA', 'pB', 'pC'],
#  'pcost': [1000, 2000, 3000]}

# %%
pd.DataFrame(products)
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000

# %%
df1 = pd.DataFrame(products)
df1
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.columns
# Out:
# Index(['pid', 'pname', 'pcost'], dtype='object')

# %%
df1.loc[1]
# Out:
# pid       102
# pname      pB
# pcost    2000
# Name: 1, dtype: object

# %%
df1.loc[0]
# Out:
# pid       101
# pname      pA
# pcost    1000
# Name: 0, dtype: object

# %%
df1['pid']
# Out:
# 0    101
# 1    102
# 2    103
# Name: pid, dtype: int64

# %%
df1['pname']
# Out:
# 0    pA
# 1    pB
# 2    pC
# Name: pname, dtype: object

# %%
products = {}
products['pid'] = [101,102,103]
products['pname'] = ['pA','pB','pC']
products['pcost'] = [1000,2000,3000]

# %%
products['pid'].append(104)
products['pname'].append('pD')
products['pcost'].append(4000)

products['pid'].append(105)
products['pname'].append('pE')
products['pcost'].append(5000)

products['pid'].append(106)
products['pname'].append('pF')
products['pcost'].append(6000)

products['pid'].append(107)
products['pname'].append('pG')
products['pcost'].append(2300)

products['pid'].append(108)
products['pname'].append('pH')
products['pcost'].append(3400)

# %%
df2 = pd.DataFrame(products)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pid     8 non-null      int64
#  1   pname   8 non-null      object
#  2   pcost   8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
df2.loc[2]
# Out:
# pid       103
# pname      pC
# pcost    3000
# Name: 2, dtype: object

# %%
df2['pid']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# Name: pid, dtype: int64

# %%
df2.loc[2:]
# Out:
#    pid pname  pcost
# 2  103    pC   3000
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
df2.loc[2:5]
# Out:
#    pid pname  pcost
# 2  103    pC   3000
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000

# %%
df2.loc[3]['pname']
# Out:
# 'pD'

# %%
df2.loc[3][['pname','pcost']]
# Out:
# pname      pD
# pcost    4000
# Name: 3, dtype: object

# %%
df2['pcost']
df2['pcost'] * 0.18
# Out:
# 0     180.0
# 1     360.0
# 2     540.0
# 3     720.0
# 4     900.0
# 5    1080.0
# 6     414.0
# 7     612.0
# Name: pcost, dtype: float64

# %%
df2['pcost'] > 3000
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# Name: pcost, dtype: bool

# %%
df2[df2['pcost'] > 3000]
# Out:
#    pid pname  pcost
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000
# 7  108    pH   3400

# %%
len(df2.index)
# Out:
# 8

# %%
df2.drop(3) #delecte 3rd rows
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000
# 4  105    pE   5000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
len(df2.index)
# Out:
# 8

# %%
df2
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000
# 3  104    pD   4000
# 4  105    pE   5000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
df3 = df2.drop(4,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4274423003.py in <cell line: 0>()
# ----> 1 df3 = df2.drop(4,inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: '[4] not found in axis'

# %%
len(df2.index)
# Out:
# 7

# %%
print(len(df2.index))
print(len(df3.index))
# Out:
# 7
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1075728750.py in <cell line: 0>()
#       1 print(len(df2.index))
# ----> 2 print(len(df3.index))
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %%
df2
# Out:
#    pid pname  pcost
# 0  101    pA   1000
# 1  102    pB   2000
# 2  103    pC   3000
# 3  104    pD   4000
# 5  106    pF   6000
# 6  107    pG   2300
# 7  108    pH   3400

# %%
df2.drop(columns='pname')
# Out:
#    pid  pcost
# 0  101   1000
# 1  102   2000
# 2  103   3000
# 3  104   4000
# 5  106   6000
# 6  107   2300
# 7  108   3400

# %%
df2.drop(columns=['pname','pcost'])
# Out:
#    pid
# 0  101
# 1  102
# 2  103
# 3  104
# 5  106
# 6  107
# 7  108

# %%
d = {'k1':[10,20,30,40,50], 'k2': ['d1','d2','d3','d4','d5'], 'k3': ['v1','v2','v3','v4','v5'], 'k4':[1,2,2, None, None]}
df = pd.DataFrame(d)
df
# Out:
#    k1  k2  k3   k4
# 0  10  d1  v1  1.0
# 1  20  d2  v2  2.0
# 2  30  d3  v3  2.0
# 3  40  d4  v4  NaN
# 4  50  d5  v5  NaN
